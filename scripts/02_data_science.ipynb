# %% [markdown]
# # Data science with Python

# %% [markdown]
# Here, we will work with a [genomics](https://en.wikipedia.org/wiki/Genomics) data set from 50 liver cancer patients.
#
# In Python, there is a module called Pandas which can be used to analyze large datasets.

# %% [markdown]
# ## Load patient data

# %%
import os

# %%
# Import the pandas module and name it "pd" (for reading tabular data)
import pandas as pd

# Import the numpy module and name it "np" (to get a lot of math-related functions)
import numpy as np

# Show plotted figures directly below the code that produces them
# %matplotlib inline

# Define the URL for the clinical data
url = "https://raw.githubusercontent.com/researchschool/researchschool/master/data/samples_phenotype.tsv"

# Read the clinical data from the URL
clinical_data=pd.read_csv(url, delimiter="\t")

# %% [markdown]
# `clinical_data` is an object, which means, we can call attributes like `clinical_data.shape` or call functions (methods) such as `data.head()`.
#
# What do the numbers mean?

# %%
clinical_data.shape
# Out:
# (366, 20)

# %%
# Check what the top lines of clinical data look like (the "head")
clinical_data.head()
# Out:
#              id submitter_id.samples  age_at_initial_pathologic_diagnosis  \
# 0  TCGA-DD-AAVQ     TCGA-DD-AAVQ-01A                                 38.0
# 1  TCGA-DD-AAE3     TCGA-DD-AAE3-01A                                 50.0
# 2  TCGA-PD-A5DF     TCGA-PD-A5DF-01A                                 58.0
# 3  TCGA-DD-AA3A     TCGA-DD-AA3A-01A                                 81.0
# 4  TCGA-G3-A3CG     TCGA-G3-A3CG-01A                                 80.0
#
#   tumor_grade tumor_stage  platelet_result_count  weight  \
# 0          G2     stage i                  128.0    72.0
# 1          G2     stage i                  180.0    73.0
# 2          G2  stage iiib                    NaN    72.0
# 3          G4     stage i                  256.0    60.0
# 4          G2     stage i                  131.0    93.0
#
#    year_of_initial_pathologic_diagnosis   ethnicity.demographic  \
# 0                                2007.0  not hispanic or latino
# 1                                2013.0  not hispanic or latino
# 2                                2007.0  not hispanic or latino
# 3                                2009.0  not hispanic or latino
# 4                                2011.0  not hispanic or latino
#
#   gender.demographic race.demographic vital_status  year_of_birth.demographic  \
# 0               male            asian        Alive                     1969.0
# 1               male            asian        Alive                     1963.0
# 2             female            white         Dead                     1949.0
# 3             female            white         Dead                     1928.0
# 4               male            white        Alive                     1931.0
#
#    bmi.exposures  height.exposures  weight.exposures  name.tissue_source_site  \
# 0      24.622961             171.0              72.0  Mayo Clinic - Rochester
# 1      26.813590             165.0              73.0  Mayo Clinic - Rochester
# 2      25.816630             167.0              72.0                Fox Chase
# 3      26.314635             151.0              60.0  Mayo Clinic - Rochester
# 4      32.950680             168.0              93.0  Alberta Health Services
#
#        project.tissue_source_site  days_to_collection.samples  \
# 0  Liver hepatocellular carcinoma                      2464.0
# 1  Liver hepatocellular carcinoma                       342.0
# 2  Liver hepatocellular carcinoma                      1906.0
# 3  Liver hepatocellular carcinoma                      1559.0
# 4  Liver hepatocellular carcinoma                       261.0
#
#    initial_weight.samples
# 0                      80
# 1                      30
# 2                     140
# 3                     100
# 4                     270

# %% [markdown]
# Let's look at how tumor stage and vital status look. Can you count how many of the samples were from Stage I,  alive patients?

# %%
clinical_data.loc[:, ['tumor_grade','tumor_stage','vital_status']]
# Out:
#     tumor_grade tumor_stage vital_status
# 0            G2     stage i        Alive
# 1            G2     stage i        Alive
# 2            G2  stage iiib         Dead
# 3            G4     stage i         Dead
# 4            G2     stage i        Alive
# ..          ...         ...          ...
# 361          G3  stage iiia        Alive
# 362          G2  stage iiib         Dead
# 363          G2  stage iiia        Alive
# 364          G3     stage i        Alive
# 365          G2     stage i        Alive
#
# [366 rows x 3 columns]

# %% [markdown]
# How many samples do we have? How many have tumor stage information? And how many belong to people who were alive when samples were collected?

# %% [markdown]
# What does the following command do?

# %%
clinical_stats=pd.DataFrame(clinical_data.groupby(['tumor_grade','vital_status'])['id'].count())
clinical_stats
# Out:
#                            id
# tumor_grade vital_status
# G1          Alive          37
#             Dead           18
# G2          Alive         117
#             Dead           60
# G3          Alive          78
#             Dead           43
#             Not Reported    1
# G4          Alive           7
#             Dead            5

# %%
clinical_stats.plot.barh()

# %% [markdown]
# ## Load a dataset

# %% [markdown]
# We will now start using the information above together with genomics data.

# %%
# Download the genomics dataset
url = "https://raw.githubusercontent.com/researchschool/researchschool/master/data/liver_cancer_study.tsv"
data = pd.read_csv(url, delimiter="\t")

# %% [markdown]
# Examine the first rows of the dataframe. What do the different columns mean? And how many rows and columns does it have? And what do the different values mean?

# %% [markdown]
# ## Tidying up the dataset

# %%
# Assign gene names as the names of the rows
data.index=data['Gene']

# Remove the descriptions
data_no_desc = data.drop(columns=['Description', 'Biological_process','Subcellular_location'])
data_no_desc.head()
# Out:
#             Gene  TCGA-DD-A4NG  TCGA-G3-AAV4  TCGA-2Y-A9H1  TCGA-BC-A10Y  \
# Gene
# CD44        CD44      3.924143      0.937697      3.035327      1.078557
# SLC7A11  SLC7A11      0.825828      2.019061      0.276539      0.131229
# ACSS2      ACSS2      4.294168      4.019318      4.736077      4.557080
# ACSS1      ACSS1      1.283499      0.577648      1.343923      1.121311
# HMOX1      HMOX1      4.410001      4.437017      4.146421      3.374783
#
#          TCGA-K7-AAU7  TCGA-BC-A10W  TCGA-DD-AACV  TCGA-DD-AAD3  TCGA-DD-A1EI  \
# Gene
# CD44         4.811782      2.855711      0.836381      1.843840      2.097177
# SLC7A11      2.174482      3.061058      0.083977      0.055147      0.908793
# ACSS2        3.030791      3.732141      5.038372      3.343817      3.606806
# ACSS1        0.791965      3.070226      0.303793      0.819981      1.065481
# HMOX1        4.163209      6.119191      3.002955      2.623993      3.844269
#
#          ...  TCGA-DD-A73C  TCGA-DD-AAW1  TCGA-XR-A8TF  TCGA-CC-A5UC  \
# Gene     ...
# CD44     ...      1.313014      2.829117      0.507286      1.787887
# SLC7A11  ...      0.021164      0.027822      0.363838      0.683047
# ACSS2    ...      4.774687      3.203448      3.279401      6.478322
# ACSS1    ...      0.633630      0.193337      0.415207      1.062016
# HMOX1    ...      5.720208      2.858821      3.008675      4.936400
#
#          TCGA-DD-A39Y  TCGA-DD-A114  TCGA-NI-A8LF  TCGA-DD-AADF  TCGA-DD-AAEI  \
# Gene
# CD44         2.387489      4.335200      1.344657      0.757303      1.323846
# SLC7A11      2.268773      0.803607      0.263856      0.086278      0.741406
# ACSS2        3.490992      3.621908      5.206280      4.972037      4.687967
# ACSS1        1.805049      1.980478      0.996611      1.634020      0.672813
# HMOX1        6.667236      6.325203      3.400283      3.435217      4.827363
#
#          TCGA-2Y-A9H5
# Gene
# CD44         1.566834
# SLC7A11      0.168173
# ACSS2        4.000064
# ACSS1        1.890890
# HMOX1        2.970664
#
# [5 rows x 367 columns]

# %%
# Show the new row names
data_no_desc.index

# Delete the protein column
data_values = data_no_desc.drop(columns="Gene")
data_values.head()
# Out:
#          TCGA-DD-A4NG  TCGA-G3-AAV4  TCGA-2Y-A9H1  TCGA-BC-A10Y  TCGA-K7-AAU7  \
# Gene
# CD44         3.924143      0.937697      3.035327      1.078557      4.811782
# SLC7A11      0.825828      2.019061      0.276539      0.131229      2.174482
# ACSS2        4.294168      4.019318      4.736077      4.557080      3.030791
# ACSS1        1.283499      0.577648      1.343923      1.121311      0.791965
# HMOX1        4.410001      4.437017      4.146421      3.374783      4.163209
#
#          TCGA-BC-A10W  TCGA-DD-AACV  TCGA-DD-AAD3  TCGA-DD-A1EI  TCGA-DD-AAC9  \
# Gene
# CD44         2.855711      0.836381      1.843840      2.097177      2.509851
# SLC7A11      3.061058      0.083977      0.055147      0.908793      0.493451
# ACSS2        3.732141      5.038372      3.343817      3.606806      5.437401
# ACSS1        3.070226      0.303793      0.819981      1.065481      0.735576
# HMOX1        6.119191      3.002955      2.623993      3.844269      4.320303
#
#          ...  TCGA-DD-A73C  TCGA-DD-AAW1  TCGA-XR-A8TF  TCGA-CC-A5UC  \
# Gene     ...
# CD44     ...      1.313014      2.829117      0.507286      1.787887
# SLC7A11  ...      0.021164      0.027822      0.363838      0.683047
# ACSS2    ...      4.774687      3.203448      3.279401      6.478322
# ACSS1    ...      0.633630      0.193337      0.415207      1.062016
# HMOX1    ...      5.720208      2.858821      3.008675      4.936400
#
#          TCGA-DD-A39Y  TCGA-DD-A114  TCGA-NI-A8LF  TCGA-DD-AADF  TCGA-DD-AAEI  \
# Gene
# CD44         2.387489      4.335200      1.344657      0.757303      1.323846
# SLC7A11      2.268773      0.803607      0.263856      0.086278      0.741406
# ACSS2        3.490992      3.621908      5.206280      4.972037      4.687967
# ACSS1        1.805049      1.980478      0.996611      1.634020      0.672813
# HMOX1        6.667236      6.325203      3.400283      3.435217      4.827363
#
#          TCGA-2Y-A9H5
# Gene
# CD44         1.566834
# SLC7A11      0.168173
# ACSS2        4.000064
# ACSS1        1.890890
# HMOX1        2.970664
#
# [5 rows x 366 columns]

# %% [markdown]
# What is the mean gene expression for each gene?

# %%
data_values.mean(1)
# Out:
# Gene
# CD44       2.101243
# SLC7A11    0.634561
# ACSS2      4.039128
# ACSS1      1.367651
# HMOX1      4.163300
#              ...
# CYBB       1.846371
# NOX5       0.017901
# SHMT1      4.617126
# GLDC       3.568760
# SHMT2      5.233773
# Length: 166, dtype: float64

# %% [markdown]
# ## Inspecting the data

# %%
# Show the expression profile of one gene for 50 samples
data_values.loc[["PKM"]].T.iloc[:50].plot()

# %%
# Show multiple proteins
data_values.loc[["PKM", "PKLR"]].T.iloc[:50].plot()

# %%
# Show the PKM and G6PD proteins
data_values.loc[["PKM", "G6PD"]].T.iloc[:50].plot()

# %% [markdown]
# Do you see any patterns when you look at the expression of PKM and PKLR? What about PKM and G6PD?
# What is your hypothesis of what is happening with these genes in terms of their expressions?

# %% [markdown]
# ## Find co-regulated genes in liver cancer
#
# Genes usually do not act on their own. They are often co-regulated to develop functions together, which means that their expression profile across all the tumors shows similar profiles. We can find such groups of co-regulated genes by comparing their expression profile with each other.
#
# In the table below, what do values $\approx1$, $\approx-1$, or $\approx0$ mean?

# %%
# Calculate a correlation matrix
corr_matrix = data_values.T.corr()

# Show the head of the correlation matrix
corr_matrix.head()
# Out:
# Gene         CD44   SLC7A11     ACSS2     ACSS1     HMOX1     HIF1A    NFE2L2  \
# Gene
# CD44     1.000000  0.315535 -0.182158  0.251430  0.479448  0.485103  0.194125
# SLC7A11  0.315535  1.000000 -0.111946  0.009233  0.225107  0.251405  0.265105
# ACSS2   -0.182158 -0.111946  1.000000 -0.014375 -0.035872 -0.259714 -0.037445
# ACSS1    0.251430  0.009233 -0.014375  1.000000  0.225347  0.346575 -0.118470
# HMOX1    0.479448  0.225107 -0.035872  0.225347  1.000000  0.265065  0.032085
#
# Gene       SQSTM1      NQO1      PFKP  ...      SOD3      SOD2     DUOX1  \
# Gene                                   ...
# CD44     0.208414  0.205814  0.503170  ...  0.325869  0.444741  0.117244
# SLC7A11  0.438700  0.305308  0.292289  ...  0.026194  0.140912  0.045169
# ACSS2    0.022768 -0.073973 -0.309945  ... -0.136633 -0.055058 -0.139763
# ACSS1   -0.074890  0.093555  0.415991  ...  0.394823  0.135008  0.297905
# HMOX1    0.216763  0.166963  0.276020  ...  0.175585  0.339561  0.004702
#
# Gene        DUOX2      SOD1      CYBB      NOX5     SHMT1      GLDC     SHMT2
# Gene
# CD44     0.235125 -0.104669  0.601382  0.114677 -0.130976 -0.210054  0.062566
# SLC7A11  0.135416 -0.052675  0.254900  0.037813 -0.234219 -0.322165  0.167225
# ACSS2   -0.165449  0.211505 -0.165936 -0.103561  0.330007  0.146469  0.055558
# ACSS1    0.229943 -0.370328  0.379157  0.090738 -0.325320  0.074193 -0.086966
# HMOX1    0.088412 -0.162749  0.540194  0.028067 -0.150079 -0.014187  0.174850
#
# [5 rows x 166 columns]

# %% [markdown]
# Let's examine the correlations for PKM, PKLR, G6PD and PRDX1

# %%
corr_matrix.loc[['PKM','PKLR','G6PD','PRDX1'],['PKM','PKLR','G6PD','PRDX1']]
# Out:
# Gene        PKM      PKLR      G6PD     PRDX1
# Gene
# PKM    1.000000 -0.534616  0.667504  0.152539
# PKLR  -0.534616  1.000000 -0.281347 -0.096287
# G6PD   0.667504 -0.281347  1.000000  0.519483
# PRDX1  0.152539 -0.096287  0.519483  1.000000

# %% [markdown]
# Look again at the expression of PKM + G6PD, PKM + PKLR, and PKM + PRDX1. Can you explain the correlations above? What is a good and a bad correlation?

# %%
#data_log.loc[["PKM", "G6PD"]].T.iloc[1:].plot()

# %% [markdown]
# ### Visualise the correlation matrix

# %%
import seaborn as sns

sns.heatmap(corr_matrix, cmap="RdBu_r", center=0)

# %% [markdown]
# We cannot really see what is going on... Let's structure the data with some machine learning.

# %% [markdown]
# ### Data clustering

# %% [markdown]
# When you cluster the correlation matrix above, do you see anything particular in the new heatmap?

# %%
sns.clustermap(corr_matrix, cmap="RdBu_r", center=0)

# %% [markdown]
# Let's focus on a few genes in addition to those we've looked above

# %%
genes_of_interest=[
    'PKM','PKLR','G6PD','PRDX1','ALDOA','MTHFD1L','GLRX3','RPIA','GLS','TXNDC9',
    'HIF1A','MTHFS','ALDOB','SHMT1','ALDH8A1','ALDH7A1','MTHFD1','ALDH5A1','CAT',
    'ALDH6A1','ALDH2','ACSS1','ACSS2']

sns.clustermap(
    corr_matrix.loc[genes_of_interest,genes_of_interest], 
    cmap="RdBu_r", center=0
)

# %% [markdown]
# ## Compare expression through cancer progression
# Liver cancer comes in different subgroups, which may depend on the tumor progression. Let's see how the genes above are expressed at different tumor stages by comparing early (Grade 1) with advanced (Grades III + IV) cancers

# %%
# Use only the 'id' and 'tumor_stage' columns
clinical_data=clinical_data.loc[:,['id','tumor_grade']]

# Drop rows with no tumor stage information
clinical_data=clinical_data.loc[clinical_data.tumor_grade!='not reported']

clinical_data.head()
# Out:
#              id tumor_grade
# 0  TCGA-DD-AAVQ          G2
# 1  TCGA-DD-AAE3          G2
# 2  TCGA-PD-A5DF          G2
# 3  TCGA-DD-AA3A          G4
# 4  TCGA-G3-A3CG          G2

# %% [markdown]
# We will compare samples from early cancer (G1) vs advanced cancer (G3+G4).

# %%
# Get the IDs from samples from early / advanced cancer
early_cancer=clinical_data.loc[clinical_data.tumor_grade=='G1', 'id'].values
adv_cancer=clinical_data.loc[clinical_data.tumor_grade.isin(['G3','G4', 'id'])].values

# Get samples belonging to either early or advanced cancer
ear_adv_samples=data_values.loc[:,data_values.columns.isin(np.append(early_cancer, adv_cancer))]

# Look at the genes of interest
ear_adv_samples=ear_adv_samples.loc[genes_of_interest]

# %%
sns.clustermap(ear_adv_samples, cmap="viridis", z_score=0)

# %% [markdown]
# Let's look at the expression of PKM, PKLR, G6PD, and ALDH2 in different tumor groups

# %%
# Select genes and samples
data_ear_adv_genes=ear_adv_samples.copy().loc[['PKM','G6PD','PKLR','ALDH2']]

# Rename samples to "early" and "adv" to make it easier to understand
data_ear_adv_genes.columns=np.append(np.repeat('early',len(early_cancer)),np.repeat('adv',len(adv_cancer)))

data_ear_adv_genes=data_ear_adv_genes.stack().reset_index().rename(columns={'level_1':'progression',0:'expression'})
data_ear_adv_genes.head()
# Out:
#   Gene progression  expression
# 0  PKM       early    2.485179
# 1  PKM       early    3.774239
# 2  PKM       early    4.814463
# 3  PKM       early    2.644124
# 4  PKM       early    2.946841

# %%
# Look at the expression of the different genes with respect to the tumor progression
sns.barplot(
    data=data_ear_adv_genes,
    x='Gene', y='expression', hue='progression'       
           )

# %% [markdown]
# What can you say about the expression of PKM, G6PD, PKLR and ALDH2 in early and advanced tumors?
# What about their co-expression patterns?
# Does this accept support your hypothesis, or do you need to modify it?
